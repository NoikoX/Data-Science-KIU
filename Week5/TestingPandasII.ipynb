# %%
from faker import Faker
import pandas as pd
import numpy as np
import random

# %%
fake = Faker()

def generate_sample_data(n_rows):
    data = {
        "Name": [fake.name() for _ in range(n_rows)],
        "Age": [random.randint(18, 80) for _ in range(n_rows)],
        "Salary": [round(random.uniform(30_000, 150_000), 2) for _ in range(n_rows)],
        "City": [fake.city() for _ in range(n_rows)],
        "Joining_Date": [fake.date_this_decade() for _ in range(n_rows)],
        "Email": [fake.email() for _ in range(n_rows)],
        "Description": [fake.text() for _ in range(n_rows)],
    }
    return pd.DataFrame(data)

# %%
df = generate_sample_data(50)
df.head()
# df.to_csv('data.csv', index=False)
# Out:
#                  Name  Age     Salary             City Joining_Date  \
# 0        Henry Miller   53   61833.45       Gilesshire   2020-02-04
# 1      Angela Estrada   25  128743.07        Anitaberg   2021-11-25
# 2     Tiffany Mendoza   73  149451.82  South Ericmouth   2020-04-09
# 3     Linda Alexander   46  104631.86        Saramouth   2024-06-28
# 4  Christina Mitchell   69   45145.86        Meganberg   2020-02-27
#
#                      Email                                        Description
# 0     robert14@example.net        Read leg happy forget degree above hundred.
# 1       bmoore@example.com  Price story agency not by must. School also bl...
# 2  savannahlee@example.com  Will very probably present. Again sure grow ni...
# 3  carneybrian@example.org  Situation floor only spring almost baby edge a...
# 4     xspencer@example.com  Both collection money rule.\nStage military le...

# %%
filtered_by_salary = df[df["Salary"] > 100_000]
filtered_by_salary.head()
# Out:
#               Name  Age     Salary             City Joining_Date  \
# 1   Angela Estrada   25  128743.07        Anitaberg   2021-11-25
# 2  Tiffany Mendoza   73  149451.82  South Ericmouth   2020-04-09
# 3  Linda Alexander   46  104631.86        Saramouth   2024-06-28
# 5     Karen Hurley   78  127454.56    Buchananhaven   2023-04-05
# 7      Debbie Wolf   70  101022.70      Sanchezside   2023-12-06
#
#                         Email  \
# 1          bmoore@example.com
# 2     savannahlee@example.com
# 3     carneybrian@example.org
# 5  brandonproctor@example.net
# 7      nhernandez@example.net
#
#                                          Description
# 1  Price story agency not by must. School also bl...
# 2  Will very probably present. Again sure grow ni...
# 3  Situation floor only spring almost baby edge a...
# 5  Girl clear sell since play doctor current. Res...
# 7  North else our answer. Myself Republican draw ...

# %%
df["Date"] = pd.to_datetime(df["Joining_Date"])

filtered_by_date = df[df["Date"] > "2023-01-01"]

filtered_by_date.head()
# Out:
#               Name  Age     Salary           City Joining_Date  \
# 3  Linda Alexander   46  104631.86      Saramouth   2024-06-28
# 5     Karen Hurley   78  127454.56  Buchananhaven   2023-04-05
# 6       Kirk Lopez   48   70513.30    Carterhaven   2023-12-06
# 7      Debbie Wolf   70  101022.70    Sanchezside   2023-12-06
# 9  Amanda Townsend   59   67186.28    Denisemouth   2023-10-25
#
#                         Email  \
# 3     carneybrian@example.org
# 5  brandonproctor@example.net
# 6       ericgreen@example.org
# 7      nhernandez@example.net
# 9   lindamckinney@example.com
#
#                                          Description       Date
# 3  Situation floor only spring almost baby edge a... 2024-06-28
# 5  Girl clear sell since play doctor current. Res... 2023-04-05
# 6  Two sell right food. Wide analysis security me... 2023-12-06
# 7  North else our answer. Myself Republican draw ... 2023-12-06
# 9  Open especially answer deal point attorney los... 2023-10-25

# %%
missing_description = df[df["Description"].isna()]

missing_description.head()
# Out:
# Empty DataFrame
# Columns: [Name, Age, Salary, City, Joining_Date, Email, Description, Date]
# Index: []

# %%
valid_email = df[df["Email"].notna()]

valid_email.head()
# Out:
#                  Name  Age     Salary             City Joining_Date  \
# 0        Henry Miller   53   61833.45       Gilesshire   2020-02-04
# 1      Angela Estrada   25  128743.07        Anitaberg   2021-11-25
# 2     Tiffany Mendoza   73  149451.82  South Ericmouth   2020-04-09
# 3     Linda Alexander   46  104631.86        Saramouth   2024-06-28
# 4  Christina Mitchell   69   45145.86        Meganberg   2020-02-27
#
#                      Email                                        Description  \
# 0     robert14@example.net        Read leg happy forget degree above hundred.
# 1       bmoore@example.com  Price story agency not by must. School also bl...
# 2  savannahlee@example.com  Will very probably present. Again sure grow ni...
# 3  carneybrian@example.org  Situation floor only spring almost baby edge a...
# 4     xspencer@example.com  Both collection money rule.\nStage military le...
#
#         Date
# 0 2020-02-04
# 1 2021-11-25
# 2 2020-04-09
# 3 2024-06-28
# 4 2020-02-27

# %%
# Filtering based on munltiple conditions

high_salary_young = df[
    (df["Salary"] > 100_000) & (df["Age"] < 40)
]
high_salary_young.head()
# Out:
#                Name  Age     Salary            City Joining_Date  \
# 1    Angela Estrada   25  128743.07       Anitaberg   2021-11-25
# 29     Carol Martin   32  133071.55    West Barbara   2021-11-18
# 33  Kevin Dominguez   26  108779.96  Katherineville   2022-02-11
# 39   Kevin Harrison   27  133119.19    East Carolyn   2021-09-15
# 42    Larry Johnson   25  120445.35  East Donnaberg   2023-09-24
#
#                         Email  \
# 1          bmoore@example.com
# 29     blairbruce@example.net
# 33  madisonharris@example.com
# 39    martindiane@example.com
# 42      zachary61@example.net
#
#                                           Description       Date
# 1   Price story agency not by must. School also bl... 2021-11-25
# 29  Feeling not gas administration than technology... 2021-11-18
# 33  Go never stop. Local officer recent media cand... 2022-02-11
# 39  Agency or meet long sea contain. Green public ... 2021-09-15
# 42  Talk others activity piece only tell science.\... 2023-09-24

# %%
# Filter rows when a numeric value is in range

age_range = df[df["Age"].between(25, 40)]

age_range.head()
# Out:
#                           Name  Age     Salary             City Joining_Date  \
# 1               Angela Estrada   25  128743.07        Anitaberg   2021-11-25
# 10  Mrs. Stephanie Camacho DVM   35   36686.41      Randallstad   2020-03-29
# 15                 Andrew Ryan   40  114884.58  North Keithberg   2024-09-17
# 29                Carol Martin   32  133071.55     West Barbara   2021-11-18
# 33             Kevin Dominguez   26  108779.96   Katherineville   2022-02-11
#
#                         Email  \
# 1          bmoore@example.com
# 10  antoniosteele@example.com
# 15        diane72@example.org
# 29     blairbruce@example.net
# 33  madisonharris@example.com
#
#                                           Description       Date
# 1   Price story agency not by must. School also bl... 2021-11-25
# 10  Send tonight American kitchen three admit. Dif... 2020-03-29
# 15  For we cup leader. Project red one.\nLeft view... 2024-09-17
# 29  Feeling not gas administration than technology... 2021-11-18
# 33  Go never stop. Local officer recent media cand... 2022-02-11

# %% [markdown]
# # Selecting some rows and some columns

# %%
# TODO

# %% [markdown]
# ## Working with Missing Data in Pandas

# %%
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}

df = pd.DataFrame(dict)
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
df = df.fillna(0)
df.head()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

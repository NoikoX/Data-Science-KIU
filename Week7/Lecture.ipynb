# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {'Name': ["Noe", "Vano", "Dumbo", "Ormo", "Dabota", "Kvino", "Rati", "Urji"],
        'Age': [19, 20, 20, 13, 14, 15, 16, 19]}

df = pd.DataFrame(data)
sns.boxplot(data['Age'])
# Out:
# <Axes: >

# %%
sns.violinplot(data['Age'])
# Out:
# <Axes: >

# %%
sns.pairplot(df, kind='red')
plt.show()
